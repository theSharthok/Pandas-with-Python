# %%
import pandas as pd

# %% [markdown]
# create a dictionary with mixed data types

# %%
data = {
    'name':['abc','bcd','def'],
    'age': [27,24,22],
    'occupation': ['scientist','engineer','teacher'],
    'salary': [60000,55000,70000]
}
data
# Out:
# {'name': ['abc', 'bcd', 'def'],
#  'age': [27, 24, 22],
#  'occupation': ['scientist', 'engineer', 'teacher'],
#  'salary': [60000, 55000, 70000]}

# %%
df = pd.DataFrame(data)
df
# Out:
#   name  age occupation  salary
# 0  abc   27  scientist   60000
# 1  bcd   24   engineer   55000
# 2  def   22    teacher   70000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        3 non-null      object
#  1   age         3 non-null      int64
#  2   occupation  3 non-null      object
#  3   salary      3 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 224.0+ bytes

# %%
data = {
    'name':['abc','bcd','def'],
    'age': [27,24,22],
    'occupation': ['scientist','engineer','teacher'],
    'salary': ['60000 euro','55000 euro','70000 euro']
}
data
# Out:
# {'name': ['abc', 'bcd', 'def'],
#  'age': [27, 24, 22],
#  'occupation': ['scientist', 'engineer', 'teacher'],
#  'salary': ['60000 euro', '55000 euro', '70000 euro']}

# %%
df = pd.DataFrame(data)
df
# Out:
#   name  age occupation      salary
# 0  abc   27  scientist  60000 euro
# 1  bcd   24   engineer  55000 euro
# 2  def   22    teacher  70000 euro

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        3 non-null      object
#  1   age         3 non-null      int64
#  2   occupation  3 non-null      object
#  3   salary      3 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 224.0+ bytes

# %% [markdown]
# Date time

# %%
# create a list of dates
dates = ['2023-10-04','2024-11-15','2025-01-01']

# create a dataframe with a datetime column
df1 = pd.DataFrame({'Date':dates})

# check the data type of the 'date' column
df1['Date'].dtype
# Out:
# dtype('O')

# %%
timestamps = pd.to_datetime(dates)
df2 = pd.DataFrame({'Date2': timestamps})
df2
# Out:
#        Date2
# 0 2023-10-04
# 1 2024-11-15
# 2 2025-01-01

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date2   3 non-null      datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 152.0 bytes

# %%
# create a list of dates
dates = ['2023','2024-05-30','2025']

# create a dataframe with a datetime column
df1 = pd.DataFrame({'Date':dates})

timestamps = pd.to_datetime(dates)
df2 = pd.DataFrame({'Date2': timestamps})

# check the data type of the 'date' column
df1['Date'].dtype
# Out:
# dtype('O')

# %%
df2['Date2'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date2   3 non-null      datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 152.0 bytes

# %%
df2
# Out:
#        Date2
# 0 2023-01-01
# 1 2024-05-30
# 2 2025-01-01

# %%
dates = ['2023-10-04 12:34:56.123456789','2024-05-30 13:18:13.12345','2025-01-01 18:16:24.23412']
timestamps = pd.to_datetime(dates)
df = pd.DataFrame({'Date': timestamps})
print(df['Date'].dtype)
# Out:
# datetime64[ns]

# %%
df
# Out:
#                            Date
# 0 2023-10-04 12:34:56.123456789
# 1 2024-05-30 13:18:13.123450000
# 2 2025-01-01 18:16:24.234120000

# %%
timestamps = pd.to_datetime(dates)
series = pd.Series(timestamps, name='dates')
series
# Out:
# 0   2023-10-04 12:34:56.123456789
# 1   2024-05-30 13:18:13.123450000
# 2   2025-01-01 18:16:24.234120000
# Name: dates, dtype: datetime64[ns]

# %%
series.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 3 entries, 0 to 2
# Series name: dates
# Non-Null Count  Dtype
# --------------  -----
# 3 non-null      datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 152.0 bytes

# %%
import pandas as pd

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-c714a4a0-978a-4539-82d5-165cf117d0c9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c714a4a0-978a-4539-82d5-165cf117d0c9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('Users.csv')
df
# Out:
#      id         name       phone        role  Salary  Emplyers_id (fk)
# 0  7856      Mr Abul  2255666777          BR   25000               5588
# 1  7654     Mr Babul   177555666  Supervisor   27500               6677
# 2  8768  Miss Jorina  2299000111          BR   40000               5588
# 3  5748  Mrs Morjina  1155886644          BR   38000               5588
# 4  5748  Mrs Morjina  1155886644          BR   38000               5588

# %%
df.shape
# Out:
# (5, 6)

# %%
row,col = df.shape
row , col
# Out:
# (5, 6)

# %%
#top nth rows
df.head()
# Out:
#      id         name       phone        role  Salary  Emplyers_id (fk)
# 0  7856      Mr Abul  2255666777          BR   25000               5588
# 1  7654     Mr Babul   177555666  Supervisor   27500               6677
# 2  8768  Miss Jorina  2299000111          BR   40000               5588
# 3  5748  Mrs Morjina  1155886644          BR   38000               5588
# 4  5748  Mrs Morjina  1155886644          BR   38000               5588

# %%
df.head(3)
# Out:
#      id         name       phone        role  Salary  Emplyers_id (fk)
# 0  7856      Mr Abul  2255666777          BR   25000               5588
# 1  7654     Mr Babul   177555666  Supervisor   27500               6677
# 2  8768  Miss Jorina  2299000111          BR   40000               5588

# %%
# last nth rows
df.tail()
# Out:
#      id         name       phone        role  Salary  Emplyers_id (fk)
# 0  7856      Mr Abul  2255666777          BR   25000               5588
# 1  7654     Mr Babul   177555666  Supervisor   27500               6677
# 2  8768  Miss Jorina  2299000111          BR   40000               5588
# 3  5748  Mrs Morjina  1155886644          BR   38000               5588
# 4  5748  Mrs Morjina  1155886644          BR   38000               5588

# %%
df.tail(2)
# Out:
#      id         name       phone role  Salary  Emplyers_id (fk)
# 3  5748  Mrs Morjina  1155886644   BR   38000               5588
# 4  5748  Mrs Morjina  1155886644   BR   38000               5588

# %% [markdown]
# range of entries

# %%
df[2:4]
# Out:
#      id         name       phone role  Salary  Emplyers_id (fk)
# 2  8768  Miss Jorina  2299000111   BR   40000               5588
# 3  5748  Mrs Morjina  1155886644   BR   38000               5588

# %% [markdown]
# accessing the columns

# %%
df['name']
# Out:
# 0        Mr Abul
# 1       Mr Babul
# 2    Miss Jorina
# 3    Mrs Morjina
# 4    Mrs Morjina
# Name: name, dtype: object

# %%
df.columns
# Out:
# Index(['id', 'name', 'phone', 'role', 'Salary', 'Emplyers_id (fk) '], dtype='object')

# %% [markdown]
# accessing nth columns

# %%
df[['name']] . head()
# Out:
#           name
# 0      Mr Abul
# 1     Mr Babul
# 2  Miss Jorina
# 3  Mrs Morjina
# 4  Mrs Morjina

# %%
df [['name','role']] .head()
# Out:
#           name        role
# 0      Mr Abul          BR
# 1     Mr Babul  Supervisor
# 2  Miss Jorina          BR
# 3  Mrs Morjina          BR
# 4  Mrs Morjina          BR

# %% [markdown]
# type of column

# %%
type(df['role'])
# Out:
# pandas.core.series.Series

# %%
type(df[['role']])
# Out:
# pandas.core.frame.DataFrame

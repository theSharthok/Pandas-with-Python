# %%
import pandas as pd

# %% [markdown]
# create a dictionary

# %%
data = {
    'name' : ['virat','ab','max'],
    'age' : [35, 36, 37],
    'city'  : ['delhi','capetown','canberra']
}
data
# Out:
# {'name': ['virat', 'ab', 'max'],
#  'age': [35, 36, 37],
#  'city': ['delhi', 'capetown', 'canberra']}

# %%
type(data)
# Out:
# dict

# %%
name_series = pd.Series(data['name'], name='Name')
name_series
# Out:
# 0    virat
# 1       ab
# 2      max
# Name: Name, dtype: object

# %%
type(name_series)
# Out:
# pandas.core.series.Series

# %%
df = pd.DataFrame(data)
df
# Out:
#     name  age      city
# 0  virat   35     delhi
# 1     ab   36  capetown
# 2    max   37  canberra

# %%
age_series = df['age']
age_series
# Out:
# 0    35
# 1    36
# 2    37
# Name: age, dtype: int64

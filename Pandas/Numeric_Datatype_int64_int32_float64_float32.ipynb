# %%
import pandas as pd

# %% [markdown]
# creating a data frame with integer data

# %%
data = {
    'age':[25,30,26,28,20,22,40,28],
    'salary':[50000,65000,45000,67000,32000,48000,80000,56000]
}
df = pd.DataFrame(data)
df
# Out:
#    age  salary
# 0   25   50000
# 1   30   65000
# 2   26   45000
# 3   28   67000
# 4   20   32000
# 5   22   48000
# 6   40   80000
# 7   28   56000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     8 non-null      int64
#  1   salary  8 non-null      int64
# dtypes: int64(2)
# memory usage: 256.0 bytes

# %%
df.dtypes
# Out:
# age       int64
# salary    int64
# dtype: object

# %% [markdown]
# changing data type from int64 to int32

# %%
df['age'] = df['age'].astype('int32')
df['salary'] = df['salary'].astype('int32')
df
# Out:
#    age  salary
# 0   25   50000
# 1   30   65000
# 2   26   45000
# 3   28   67000
# 4   20   32000
# 5   22   48000
# 6   40   80000
# 7   28   56000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     8 non-null      int32
#  1   salary  8 non-null      int32
# dtypes: int32(2)
# memory usage: 192.0 bytes

# %%
df.dtypes
# Out:
# age       int32
# salary    int32
# dtype: object

# %%
df['age'] = df['age'].astype('int16')
df['salary'] = df['salary'].astype('int16')
df
# Out:
#    age  salary
# 0   25  -15536
# 1   30    -536
# 2   26  -20536
# 3   28    1464
# 4   20   32000
# 5   22  -17536
# 6   40   14464
# 7   28   -9536

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     8 non-null      int16
#  1   salary  8 non-null      int16
# dtypes: int16(2)
# memory usage: 160.0 bytes

# %%
df.dtypes
# Out:
# age       int16
# salary    int16
# dtype: object

# %% [markdown]
# float data type

# %%
data = {
    'age':[25,30,26,28,20,22,40,28],
    'salary':[50000,65000,45000,67000,32000,48000,80000,56000]
}
df = pd.DataFrame(data)
df
# Out:
#    age  salary
# 0   25   50000
# 1   30   65000
# 2   26   45000
# 3   28   67000
# 4   20   32000
# 5   22   48000
# 6   40   80000
# 7   28   56000

# %%
df['age'] = df['age'].astype('float64')
df['salary'] = df['salary'].astype('float64')
df
# Out:
#     age   salary
# 0  25.0  50000.0
# 1  30.0  65000.0
# 2  26.0  45000.0
# 3  28.0  67000.0
# 4  20.0  32000.0
# 5  22.0  48000.0
# 6  40.0  80000.0
# 7  28.0  56000.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     8 non-null      float64
#  1   salary  8 non-null      float64
# dtypes: float64(2)
# memory usage: 256.0 bytes

# %%
df['age'] = df['age'].astype('float32')
df['salary'] = df['salary'].astype('float32')
df
# Out:
#     age   salary
# 0  25.0  50000.0
# 1  30.0  65000.0
# 2  26.0  45000.0
# 3  28.0  67000.0
# 4  20.0  32000.0
# 5  22.0  48000.0
# 6  40.0  80000.0
# 7  28.0  56000.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     8 non-null      float32
#  1   salary  8 non-null      float32
# dtypes: float32(2)
# memory usage: 192.0 bytes
